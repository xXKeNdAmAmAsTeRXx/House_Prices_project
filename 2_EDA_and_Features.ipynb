# %%
# imports
import pandas as pd
import numpy as np

# %% [markdown]
# # Explanatory Data Analysis and Feature Engineering
# The scope of this particular notebook is feature analysis and engineering.

# %%
data = pd.read_csv('Data/train.csv', index_col='Id')
data.head(10)
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
# 6           50       RL         85.0    14115   Pave   NaN      IR1
# 7           20       RL         75.0    10084   Pave   NaN      Reg
# 8           60       RL          NaN    10382   Pave   NaN      IR1
# 9           50       RM         51.0     6120   Pave   NaN      Reg
# 10         190       RL         50.0     7420   Pave   NaN      Reg
#
#    LandContour Utilities LotConfig  ... PoolArea PoolQC  Fence MiscFeature  \
# Id                                  ...
# 1          Lvl    AllPub    Inside  ...        0    NaN    NaN         NaN
# ...

# %% [markdown]
# ## Checking for Nans

# %%
data.isna().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
# Out:
# array([False, False,  True, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False, False, False, False, False,  True,  True, False,
#        False, False,  True,  True,  True,  True, False,  True, False,
#        False, False, False, False, False,  True, False, False, False,
#        False, False, False, False, False, False, False, False, False,
#        False, False,  True,  True,  True,  True, False, False,  True,
#         True, False, False, False, False, False, False, False,  True,
#         True,  True, False, False, False, False, False, False])

# %%
nans_mask = np.array(data.isna().sum().values > 0)

data.loc[:, nans_mask]
# Out:
#       LotFrontage Alley MasVnrType  MasVnrArea BsmtQual BsmtCond BsmtExposure  \
# Id
# 1            65.0   NaN    BrkFace       196.0       Gd       TA           No
# 2            80.0   NaN        NaN         0.0       Gd       TA           Gd
# 3            68.0   NaN    BrkFace       162.0       Gd       TA           Mn
# 4            60.0   NaN        NaN         0.0       TA       Gd           No
# 5            84.0   NaN    BrkFace       350.0       Gd       TA           Av
# ...           ...   ...        ...         ...      ...      ...          ...
# 1456         62.0   NaN        NaN         0.0       Gd       TA           No
# 1457         85.0   NaN      Stone       119.0       Gd       TA           No
# 1458         66.0   NaN        NaN         0.0       TA       Gd           No
# 1459         68.0   NaN        NaN         0.0       TA       TA           Mn
# 1460         75.0   NaN        NaN         0.0       TA       TA           No
#
# ...
