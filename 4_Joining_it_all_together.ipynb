# %%
import pandas as pd

binary = pd.read_csv('Data/binary_train_selected.csv')
ordinal = pd.read_csv('Data/ordinal_train_selected.csv')
numerical = pd.read_csv('Data/num_train_selected.csv')
time = pd.read_csv('Data/time_train_selected.csv')

full_data = pd.concat([binary, ordinal, numerical, time], axis=1).drop('Unnamed: 0', axis=1)


full_data
# Out:
#       Foundation_PConc  GarageType_Detchd  GarageType_Attchd  \
# 0                 True              False               True
# 1                False              False               True
# 2                 True              False               True
# 3                False               True              False
# 4                 True              False               True
# ...                ...                ...                ...
# 1407              True              False               True
# 1408             False              False               True
# 1409             False              False               True
# 1410             False              False               True
# 1411             False              False               True
#
#       Exterior2nd_VinylSd  MSZoning_RM  Foundation_CBlock  Neighborhood_NAmes  \
# 0                    True        False              False               False
# 1                   False        False               True               False
# 2                    True        False              False               False
# 3                   False        False              False               False
# 4                    True        False              False               False
# ...                   ...          ...                ...                 ...
# 1407                 True        False              False               False
# 1408                False        False               True               False
# 1409                False        False              False               False
# 1410                False        False               True                True
# 1411                False        False               True               False
#
#       MSZoning_RL  Exterior1st_VinylSd  SaleType_New  ...  Garage_index  \
# 0            True                 True         False  ...             5
# 1            True                False         False  ...             5
# 2            True                 True         False  ...             5
# 3            True                False         False  ...             4
# 4            True                 True         False  ...             5
# ...           ...                  ...           ...  ...           ...
# 1407         True                 True         False  ...             5
# 1408         True                False         False  ...             4
# 1409         True                False         False  ...             5
# 1410         True                False         False  ...             4
# 1411         True                False         False  ...             6
#
#       Condition_index  Living_Area     OpenSF  Luxury_index   Comf_idx  \
# 0                30.0    38.247157   7.440869      4.317259  13.873467
# 1                17.5    34.902620   4.825198      6.036094  15.530623
# 2                30.0    38.917216   6.976956      4.001528  14.329585
# 3                35.0    38.036693   3.754613      3.030397  13.374408
# 4                30.0    40.236550  12.468098      5.501664  16.435368
# ...               ...          ...        ...           ...        ...
# 1407             30.0    38.402028   3.897520      0.246362  13.513207
# 1408             12.5    36.528185   7.862977      5.841068  16.189255
# 1409             70.0    39.735171   4.337072      3.349038  14.325773
# 1410             12.5    34.245881   4.969695      2.916682  13.947536
# 1411             12.5    34.928774   9.922530      5.897605  15.022426
#
#       FullBath  LotFrontage  YearBuilt  SalePrice
# 0     1.712883    28.197481       2003     208500
# 1     1.712883    32.996821       1976     181500
# 2     1.712883    29.178737       2001     223500
# 3     0.911265    26.535234       1915     140000
# 4     1.712883    34.235344       2000     250000
# ...        ...          ...        ...        ...
# 1407  1.712883    27.204315       1999     175000
# 1408  1.712883    34.542537       1978     210000
# 1409  1.712883    28.525856       1941     266500
# 1410  0.911265    29.178737       1950     142125
# 1411  0.911265    31.425563       1965     147500
#
# [1412 rows x 25 columns]
